# %%
import pandas as pd

# %%
df = pd.read_csv('ulus.csv')
df.head()
# Out:
#                  Улусы (районы)  \
# 0     Абыйский;п. Белая Гора;69
# 1        Алданский;г. Алдан;156
# 2  Аллаиховский;п. Чокурдах;107
# 3          Амгинский;с. Амга;29
# 4     Анабарский;с. Саскылах;55
#
#    город республиканского значения;Администра-тивные центры;Площадь территории  \
# 0               4;4750;1950/2900;3243;1148;-;-;1;6;5
# 1                       8;49346;534;-;470;-;2;4;13;3
# 2                    3;3421;2700;2830;1290;-;-;1;6;5
# 3                   4;17251;201;1036;200;-;-;-;21;14
# 4                    6;4024;2621;2835;1285;-;-;-;3;3
#
#     тыс.км2;Численность населения (по данным Всероссийской переписи населения 2002  г.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df = pd.read_csv('ulus.csv', sep=';')
df.head()
# Out:
#   Улусы (районы), город республиканского значения Администра-тивные центры  \
# 0                                        Абыйский            п. Белая Гора
# 1                                       Алданский                 г. Алдан
# 2                                    Аллаиховский              п. Чокурдах
# 3                                       Амгинский                  с. Амга
# 4                                      Анабарский              с. Саскылах
#
#   Площадь территории, тыс.км2  \
# 0                        69,4
# 1                       156,8
# 2                       107,3
# 3                        29,4
# 4                        55,6
#
#    Численность населения (по данным Всероссийской переписи населения 2002  г.), человек  \
# 0                                             4750.0
# 1                                            49346.0
# 2                                             3421.0
# 3                                            17251.0
# ...

# %%
df.dtypes
# Out:
# Улусы (районы), город республиканского значения                                          object
# Администра-тивные центры                                                                 object
# Площадь территории, тыс.км2                                                              object
# Численность населения (по данным Всероссийской переписи населения 2002  г.), человек    float64
# Расст до Якт наземным                                                                    object
# Расст до Якт водным                                                                      object
# Расст до Якт воздушным                                                                   object
# городов                                                                                  object
# городов улусного                                                                         object
# поселков                                                                                 object
# ...

# %%
df.columns
# Out:
# Index(['Улусы (районы), город республиканского значения',
#        'Администра-тивные центры', 'Площадь территории, тыс.км2',
#        'Численность населения (по данным Всероссийской переписи населения 2002  г.), человек',
#        'Расст до Якт наземным', 'Расст до Якт водным',
#        'Расст до Якт воздушным', 'городов', 'городов улусного', 'поселков',
#        'сел', 'наслегов'],
#       dtype='object')

# %%
df['сел']
# Out:
# 0      6.0
# 1     13.0
# 2      6.0
# 3     21.0
# 4      3.0
# 5      9.0
# 6     29.0
# 7      5.0
# 8     26.0
# 9     25.0
# 10    16.0
# 11     5.0
# 12    22.0
# 13    16.0
# 14    35.0
# 15     8.0
# 16     7.0
# 17    24.0
# 18     2.0
# 19    12.0
# 20    23.0
# 21    13.0
# 22    52.0
# 23     4.0
# 24     NaN
# 25    14.0
# 26    39.0
# 27    15.0
# 28    12.0
# 29    35.0
# 30    10.0
# 31     7.0
# 32    27.0
# 33    30.0
# 34     4.0
# 35    11.0
# Name: сел, dtype: float64
